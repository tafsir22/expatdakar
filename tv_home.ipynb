# %%
import pandas as pd
from requests import get
from bs4 import BeautifulSoup as bs

# %%
df = pd.DataFrame()

for page in range(1, 187):  
    url = f'https://www.expat-dakar.com/tv-home-cinema?page={page}'
    print(url)
    res = get(url)
    soup = bs(res.text, 'html.parser')
    containers = soup.find_all('div', class_='listings-cards__list-item') 

    data = []
    for container in containers:
        try:
            url_container = container.find('a', class_='listing-card__inner')['href']
            res_c = get(url_container)
            soup_c = bs(res_c.text, 'html.parser')
         
            dd_elements = soup_c.find_all('dd', class_="listing-item__properties__description")
            
            etat = dd_elements[0].text.strip()
            marque = dd_elements[1].text.strip()
            details = soup_c.find('h1', class_ = "listing-item__header")
            price = soup_c.find('span', class_="listing-card__price__value 1").text.strip().replace('F Cfa', '')
            address = soup_c.find('span', class_="listing-item__address-location").text.strip()
            image_link = soup_c.find('img', class_="gallery__image__resource vh-img").get('src', '')
           
            dic = {
                'details': details,
                'Etat': etat,
                'Marque': marque,
                'Prix': price,
                'Adresse': address,
                'Image_link': image_link
            }
            data.append(dic)
        except Exception as e:
            pass
            # print(f"Erreur lors du traitement d'un conteneur : {e}")
    DF = pd.DataFrame(data)
    df = pd.concat([df,DF], axis=0).reset_index(drop=True)

# %%
df.to_csv('tv_home.csv')

# %%
df = pd.DataFrame(data)
df.shape
# Out:
# (9, 6)

# %%
df
# Out:
#                                              details    Etat   Marque  \
# 0  [\n    télévision STAR TRACK SMART TV 75 pouce...    Neuf     Star
# 1                        [\n    Box tv 4k android\n]    Neuf    Autre
# 2                        [\n    Tv box android 11\n]    Neuf    Autre
# 3           [\n    NVIDIA Shield TV Box + manette\n]  Venant    Autre
# 4             [\n    Tv HISENSE 32" Smart Android\n]    Neuf  Hisense
# 5                            [\n    Box tv 8k pro\n]    Neuf  Toshiba
# 6                          [\n    Box tv 8k HDR10\n]    Neuf    Autre
# 7                        [\n    Android box T95s1\n]    Neuf    Autre
# 8                 [\n    CLIMATISEUR MOBILE 1.5CV\n]    Neuf    Autre
#
#        Prix       Adresse                                         Image_link
# 0  690 000         Médina  https://i.roamcdn.net/hz/ed/listing-thumb-543w...
# 1   25 000     Grand-Yoff  https://i.roamcdn.net/hz/ed/listing-thumb-543w...
# 2   35 000     Grand-Yoff  https://i.roamcdn.net/hz/ed/listing-thumb-543w...
# 3  200 000     Grand-Yoff  https://i.roamcdn.net/hz/ed/listing-thumb-543w...
# 4   95 000        Plateau  https://i.roamcdn.net/hz/ed/listing-thumb-543w...
# 5   35 000     Grand-Yoff  https://i.roamcdn.net/hz/ed/listing-thumb-543w...
# 6   45 000     Grand-Yoff  https://i.roamcdn.net/hz/ed/listing-thumb-543w...
# 7   30 000      Dieuppeul  https://i.roamcdn.net/hz/ed/listing-thumb-543w...
# 8  165 000   Gueule-Tapée  https://i.roamcdn.net/hz/ed/listing-thumb-543w...
